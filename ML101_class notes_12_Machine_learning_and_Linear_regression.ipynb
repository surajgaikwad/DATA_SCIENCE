# %% [markdown]
# simple linear regresiion : Y_pred = B1 X + B0
# Multiple variables : y_pred = B1 x1 + B2 X2 + B3 X3 +..........Bn Xn + B0

# %%
import pandas as pd

# %%
df = pd.DataFrame({"X":[1,2,3,4,5],"y":[6,7,8,9,10],"y1":[10,13,16,19,22],"y2":[9,13,17,21,25]})
df
# Out:
#    X   y  y1  y2
# 0  1   6  10   9
# 1  2   7  13  13
# 2  3   8  16  17
# 3  4   9  19  21
# 4  5  10  22  25

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["X"],df["y"])
plt.plot(df["X"],df["y1"],marker="*")
plt.plot(df["X"],df["y2"],marker="o")

# %%
df2 = pd.DataFrame({"X":[1,2,3,4,5],"y":[6,7,8,9,10]})
df2
# Out:
#    X   y
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(df2[["X"]],df2["y"]) # double squre bracket becoz it can be of multiple columns
# Out:
# LinearRegression()

# %%
model.coef_ # B1
# Out:
# array([1.])

# %%
model.intercept_ # B0  ----> y = X + 4.99999999999 (MODEL) (least mean squre error for this model)
# Out:
# 4.999999999999999

# %%
ypred = model.predict(df2[["X"]]) # double squre bracket becoz it can be of multiple columns 
ypred
# Out:
# array([ 6.,  7.,  8.,  9., 10.])

# %%
from sklearn.metrics import mean_squared_error 
mean_squared_error(df2["y"],ypred)
# Out:
# 1.5777218104420237e-31

# %%
round(mean_squared_error(df2["y"],ypred))
# Out:
# 0

# %%
df3 = pd.DataFrame({"X":[1,2,3,4,5],"y":[6,7,8,9,11]})
df3
# Out:
#    X   y
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  11

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(df3[["X"]],df3["y"])
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([1.2])

# %%
model.intercept_
# Out:
# 4.599999999999998

# %%
ypred2 = model.predict(df3[["X"]]) 
ypred2
# Out:
# array([ 5.8,  7. ,  8.2,  9.4, 10.6])

# %%
from sklearn.metrics import mean_squared_error as mse
mse(df3["y"],ypred2)
# Out:
# 0.07999999999999993

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ![Machine_learning.jpg](attachment:Machine_learning.jpg)

# %% [markdown]
# ## Introduction to Machine Learning

# %% [markdown]
# * While working at IBM in 1959, Arthur Samuel, a pioneering American in the fields of artificial intelligence and video games, invented the phrase "Machine Learning." "The field of research that gives computers the ability to learn without being explicitly programmed," he said of machine learning. There isn't a single definition of machine learning, though. The phrase has been defined variously by several authors.
# <br><br>
# * Machine learning is a field of data science that employs statistical techniques to enhance performance based on prior knowledge or find novel patterns in vast amounts of data.
# <br><br>
# * Self-improving algorithms are used in machine learning, which is a crucial component. Self-improving algorithms make decisions based on past experience and trial and error, just like humans do.
# <br><br>
# * In addition to thinking and learning like humans, machine learning is also more efficient. Simply put, humans lack the inclination to perform repetitive jobs with the same consistency and competence as computers do when handling data. In addition, big data generation can scale up beyond our finite human capacities in terms of quantity, complexity, and speed.
# <br><br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Importance of Machine Learning

# %% [markdown]
# Nearly every industry, including healthcare, finance, infrastructure, marketing, self-driving cars, recommendation systems, chatbots, social media, gaming, cyber security, and many others, uses machine learning techniques.
# It benefits us in a variety of ways, including large-scale data analysis, data extraction, interpretation, etc. As a result, there are countless applications for machine learning.
# <br><br>
# A fundamental component of artificial intelligence is machine learning, which enables computers to learn from the past and predict the future. Data exploration and pattern matching are involved, with little assistance from humans.
# <br><br>
# Even though there are constantly new technologies emerging, machine learning is still utilised in a number of different industries.
# <br><br>
# Machine learning is significant because it aids in the development of new goods and provides businesses with a picture of trends in consumer behaviour and operational business patterns. A significant portion of the operations of many of today's top businesses, like Facebook, Google, and Uber, revolve around machine learning. For many businesses, machine learning has emerged as a key competitive differentiation.
# <br><br>
# A company's future may be significantly impacted by machine learning because it has a number of real-world uses that produce tangible commercial outcomes like time and cost savings. Particularly, we observe a significant impact on the customer care sector, where machine learning is enabling humans to complete tasks more quickly and effectively.

# %% [markdown]
# ##  Types of Machine Learning

# %% [markdown]
# There are mainly four technologies that machine learning used to work.
#
# ![Types_of_ML.png](attachment:Types_of_ML.png)

# %% [markdown]
# ### Supervised Learning

# %% [markdown]
# * A machine learning technique called "supervised learning" necessitates monitoring just like a student-teacher interaction does.
# * In supervised learning, a machine is trained using data that has already been correctly labelled with some of the outputs.
# * As a result, supervised learning algorithms assess sample data whenever new data is entered into the system and use that labelled data to predict accurate results.
# * Regression and classification are the two different groups of algorithms that it falls under.

# %% [markdown]
# **Classification**: It deals when output is in the form of a category such as Yellow, blue, right or wrong, etc.
# <br><br>
# **Regression**: It deals when output variables are real values like age, height, etc.
#
# ![Classification_vs_reg.png](attachment:Classification_vs_reg.png)

# %% [markdown]
# ### Unsupervised Learning

# %% [markdown]
# * Unlike supervised learning, unsupervised Learning does not require classified or well-labeled data to train a machine.
# * It aims to make groups of unsorted information based on some patterns and differences even without any labelled training data.
# * In unsupervised Learning, no supervision is provided, so no sample data is given to the machines. Hence, machines are restricted to finding hidden structures in unlabeled data by their own.
# * It is classified into two different categories of algorithms, **clustering** and **association**

# %% [markdown]
# **Clustering**: It deals when there is a requirement of inherent grouping in training data, e.g., grouping students by their area of interest.
# <br><br>
# **Association**: It deals with the rules that help to identify a large portion of data, such as students who are interested in ML and also interested in AI.
# ![Cluster_association.jpeg](attachment:Cluster_association.jpeg)

# %% [markdown]
# ### Semi-supervised learning

# %% [markdown]
# Combining supervised and unsupervised learning techniques is known as semi-supervised learning.
# It is used to get around both supervised and unsupervised learning's shortcomings.
# In the semi-supervised learning approach, both labelled and unlabeled data are used to train the machine. Nevertheless, it includes both a sizable number of unlabeled cases and a few examples with labels.
# Some of the most common semi-supervised learning real-world applications are speech analysis, web content categorization, protein sequence classification, and text document classifiers.
#
# ![semi_supervised.png](attachment:semi_supervised.png)

# %% [markdown]
# ### Reinforcement learning

# %% [markdown]
# * A feedback-based machine learning technique known as reinforcement learning is one that excludes the need for labelled data.
# * Through performing actions and observing how they affect the environment, an agent learns how to behave there.
# * Agents can offer compliments for each constructive action and criticism for destructive ones.
# * Since there are no training data for reinforcement learning, agents can only learn from their experience.

# %% [markdown]
# **Use cases of Machine Learning Technology**
#
# Machine learning is widely employed across many industries and has a wide range of uses, particularly when it comes to gathering, analysing, and responding to massive amounts of data. These significant applications help us to understand the significance of machine learning.
#
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# **There are Seven Steps of Machine Learning**
#
# * Gathering Data
# * Preparing that data
# * Choosing a model
# * Training
# * Evaluation
# * Hyperparameter Tuning
# * Prediction
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Supervised Machine learning

# %% [markdown]
# ### Regression

# %% [markdown]
# Regression analysis uses one or more independent variables to describe the relationship between a dependent (target) and independent (predictor) variables.
# <br><br>
# More specifically, regression analysis enables us to comprehend how, while other independent variables are held constant, the value of the dependent variable changes in relation to an independent variable.
# <br><br>
# It forecasts continuous values like temperature, age, pay, and price, among others.
# <br><br>
# It is mostly used for forecasting, time series modeling, prediction, and establishing the causal connection between variables.
# <br><br>
# Regression involves creating a graph that connects the variables that best fit the given data points. The machine learning model can then predict the data using this plot.
# <br><br>
# Regression is defined as "showing a line or curve that goes through all of the data points on the target-predictor graph in such a way that the vertical distance between the data points and the regression line is smallest."
# <br><br>
# Whether a model has captured a strong link or not is determined by the distance between the datapoints and the line.
# <br><br>
#
# **Some examples of regression can be as:**
#
# * Prediction of rain using temperature and other factors
# * Determining Market trends
# * Prediction of road accidents due to rash driving.

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# A statistical regression technique used for predictive analysis is called linear regression.
# <br><br>
# One of the most basic and straightforward algorithms, it uses regression to illustrate the relationship between continuous variables.
# <br><br>
# It is applied to the machine learning regression problem.
# <br><br>
# The term "linear regression" refers to a statistical method that displays a linear relationship between the independent variable (X-axis) and the dependent variable (Y-axis).
# <br><br>
# Such linear regression is referred to as simple linear regression if there is only one input variable (x). Additionally, this type of linear regression is known as multiple linear regression if there are many input variables.
# <br><br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Below is the mathematical equation for Linear regression:
#
#      Y= aX+b
#
# Here,
#
#  * Y = dependent variables (target variables),
#
#  * X= Independent variables (predictor variables),
#
#  * a and b are the linear coefficients
#
# * Linear regression algorithm shows a linear relationship between a dependent (y) and one or more independent (y) variables, hence called as linear regression.
# <br><br>
#
#
#
# * Types of Linear Regression
# Linear regression can be further divided into two types of algorithms:
#
#   * **Simple Linear Regression**:
#     Only one independent variable is used to predict the continuous dependent variable.
#   * **Multiple Linear regression**:
#     Multiple independent variable is used to predict the continuous dependent variable..

# %% [markdown]
# **Finding the best fit line:**
# * Finding the best fit line is crucial when using linear regression since it minimises the difference between the predicted and actual values.
# * The line with the least inaccuracy will have the best fit.
# * We need to determine the best values for a0 and a1 to find the best fit line, thus to do this we utilise the cost function. The varied values for weights or the coefficient of lines (a0, a1) gives a distinct line of regression.

# %% [markdown]
# ### Ordinary least squares (OLS)
# Important link: https://setosa.io/ev/ordinary-least-squares-regression/
# - The vertical distance between a real data point and the regression line, or the difference between a prediction and reality, is called error.
# - Squares of errors are important to OLS.
# - The line through the sample data that minimises the sum of squared errors is sought after.

# %% [markdown]
# ### Residuals
# * The term "residual" refers to the difference between the actual value and the expected values.
# * The residual and cost function will be high if the observed points are far from the regression line.
# * The residual will be tiny if the scatter points are close to the regression line, and the cost function will follow..
# ![residual.png](attachment:residual.png)

# %% [markdown]
# ### Cost function
# The cost function is used to estimate the values of the coefficient for the line with the best fit. The varied values for weights or coefficient of lines (a0, a1) gives the different line of regression.
# <br><br>
# The regression coefficients or weights are optimised by the cost function. It gauges the effectiveness of a linear regression model.
# <br><br>
# The mapping function, which converts the input variable to the output variable, can be evaluated using the cost function to determine its accuracy. The name Hypothesis Function is another name for this mapping function.
# <br><br>
# We utilise the Mean Squared Error (MSE) cost function for linear regression, which is the average of the squared errors between the predicted and actual values.
#
# ### Regression Evaluation Metrics
#
#
# Here are three common evaluation metrics for regression problems:
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# All of these are **loss functions**, because we want to minimize them.

# %% [markdown]
# ### Gradient Descent
#
# * The MSE is reduced via gradient descent by determining the gradient of the cost function.
# * By lowering the cost function, a regression model employs gradient descent to update the coefficients of the line.
# * To achieve the minimal cost function, coefficient values are randomly chosen and then iteratively updated.
# <br><br>
#
# ### Model Performance
# * How well the regression line fits the data set is determined by the goodness of fit.
# * Optimization is the process of selecting the best model from a group of competing models. It can be done using the following method:
#
# * R-squared technique or cofficient of determination
#
#     - A statistical technique that assesses the goodness of fit is R-squared.
#     - On a scale of 0 to 1, it assesses how much variance in the outcome variable can be explained by the predcitors.
#     - For multiple linear regression we use adjusted R-squared

# %% [markdown]
# ### Assumptions of Linear Regression
#
# Linear relationship between the dependent and independent continuous variables
# <br><br>
# Small or no multicollinearity between independent features
# <br><br>
# Homoscedasticity: no clear pattern in error term
# <br><br>
# Normal distribution of error
# <br><br>
# No autocorrelations

# %% [markdown]
# ### Simple Linear Regression
#
# * Relationship between a dependent variable and a single independent variable.
# <br><br>
# * The relationship is linear or a sloped straight line.
# <br><br>
#
#
#   y= a+b1x+ ε
#
# Where,
#
# a= It is the intercept of the Regression line
# <br><br>
# b1= It is the slope of the regression line
# <br><br>
# ε = The error term.

# %%
# Importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
USAhousing = pd.read_excel('ML101 Dataset_6 USA_Housing.xlsx') #reading the dataset

# %% [markdown]
# ### Basic exploration of the data

# %%
USAhousing.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
USAhousing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
USAhousing.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
USAhousing.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %% [markdown]
# ### Q1: Do you think Avg, Area House Age will affect the house price?

# %% [markdown]
# - Here Avg, Area House Age is independent variable and house price is dependent variable.
# - As we are just examinig one independent variable, and dependent variable is continuous, it is an example of simple linear regression.

# %% [markdown]
# ### Q2: Do you think all variables will affect the house price?¶
# - This is an example of multiple linear regression, as we are adding multiple independent variables in the model.
# - In reallife, multiple factors affect the prediction.

# %% [markdown]
# ## EDA
#
# Let's create some simple plots to check out the data!

# %%
sns.pairplot(USAhousing)

# %% [markdown]
# - From the pairplot, it is very clear that **Avg. Area House Age and Price have linear relationship**.
# - Histogram also suggests that both variables are normally distributed.
# - We can also create a scatter plot to examine the linear relationship between Avg. Area House Age and Price
# - Similarly, we can create histogram to examine the normal distribution plot seperately for Avg. Area House Age and Price.

# %%
sns.distplot(USAhousing['Price'])
# Out:
# C:\Users\Expert\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
# Examinig correlation value
# By default it will use pearson correlation. As all assumptions of pearson correlation is meeting, hence we are good to go with 
# pearson correlation, otherwise we should have used spearman correlation
# Correlation analysis cannot be used for categorical values.
USAhousing.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.002007
# Avg. Area House Age                  -0.002007             1.000000
# Avg. Area Number of Rooms            -0.011032            -0.009428
# Avg. Area Number of Bedrooms          0.019788             0.006149
# Area Population                      -0.016234            -0.018743
# Price                                 0.639734             0.452543
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.011032
# Avg. Area House Age                           -0.009428
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462695
# Area Population                                0.002040
# Price                                          0.335664
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# ...

# %%
# Increase the size of the heatmap.
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(USAhousing.corr(), vmin=-1, vmax=1, annot=True)
# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# ## Training a Linear Regression Model
# First split the dataset into an X array containing features and Y array (price) with the target varaible. Address wil be romoved as does not contain important information untill specific location.
#
#
# ### X and y arrays

# %%
x = USAhousing[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
               'Avg. Area Number of Bedrooms', 'Area Population']]
y = USAhousing.Price

# %%
x # multiple linear regression     y_pred = B1 X1 + B2 X2 + .........+Bn Xn + Bo
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09     23086.800503
# ...

# %% [markdown]
# ## Train Test Split
#
# Splitting the dataset in training and test set.

# %%
from sklearn.model_selection import train_test_split # importing train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=101) #25% is test and 75% is training

# %% [markdown]
# ### Feature scaling
# - Perform to create same scale for all variables.
# - Hence, all variables will have similar influnece on the model

# %%
from sklearn.preprocessing import StandardScaler # performing standardization technique
sc = StandardScaler()
X_train=sc.fit_transform(X_train)
X_train
# Out:
# array([[ 0.34529318, -0.84306952,  0.57820121, -0.37429069, -1.75053875],
#        [-0.18466794, -0.276508  , -0.07456069, -0.45561391, -0.82511745],
#        [ 0.92874457, -1.77295774,  0.48319053,  1.08139504,  0.62832369],
#        ...,
#        [-1.20951742, -2.28499865, -0.11524894, -1.35016939,  2.72022392],
#        [-0.50924621, -0.03693705, -1.07263584,  0.11364866, -0.34921044],
#        [ 0.62611608,  1.710467  ,  1.46138542,  0.30069208,  2.01117877]])

# %%
X_test=sc.transform(X_test)
X_test
# Out:
# array([[-0.15729399, -0.25988925,  0.81415034,  0.29255976,  0.060295  ],
#        [-0.59037423, -1.06881363,  0.44564321,  1.83770103, -1.02608998],
#        [ 0.49066373,  0.81308473,  1.35746786, -0.50440785,  0.70152044],
#        ...,
#        [-1.14875303, -0.13592128,  0.91335013, -0.61826036,  0.43356126],
#        [-0.41492811, -1.42058488, -1.11050095,  0.11364866, -0.32749263],
#        [ 0.19604896,  0.67145888, -0.83866824,  0.42267692,  1.55678549]])

# %% [markdown]
# ## Creating and Training the Model

# %%
# Importing MAE, rsq, MSE and liner regression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
# regression coefficients
print('Coefficients: ', lm.coef_)
print("Intercept: ",lm.intercept_ )
# Out:
# Coefficients:  [229351.07160252 161315.32652344 120974.10877093   2231.32988299
#  151328.44980526]
# Intercept:  1228547.7798345655

# %%
model --> 229351.07160252 *X1+ 161315.32652344*X2+120974.10877093*X3+ 2231.32988299*x4 + 151328.44980526*x5+1228547.7798345655

# %%
lm.predict([[65000,5.4,6.3,4.05,50000]]) # to predict on any future value , price =
# Out:
# array([2.2477113e+10])

# %%
# Importing MAE , req , MSE , and linear regression

# from sklearn.metrics import mean_squared_error
# from sklearn.metrics import r2_score

# %%
from sklearn.metrics import mean_squared_error as mse
y_pred = lm.predict(X_train)
mse(y_train,y_pred)
# Out:
# 10174329724.586687

# %%
from sklearn.metrics import r2_score    # r^2 = 1- (( sigma(y_train - y_pred)**2)/sigma(y_train-)) # see formula on google

r2 = r2_score(y_true=y_train,y_pred=y_pred)   # r**2 ---> coefficient of determination - accuracy of the prectidctive problem 
r2
# Out:
# 0.9182890812981098

# %%
from sklearn.metrics import mean_squared_error as mse
y_pred = lm.predict(X_test)
mse(y_test,y_pred)
# Out:
# 10364756049.538397

# %%
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.9170626478020512

# %% [markdown]
# The **coefficient of determination (R²)** is a number between 0 and 1 that measures how well a statistical model predicts an outcome.

# %% [markdown]
# |Coefficient of determination (R2)|Interpretation|
# |---|---|
# |0|does not predict the outcome|
# |0 and 1|partially predicts the outcome|
# |1|Perfectly predicts the outcome|

# %% [markdown]
# R2 is a measure of goodness of fit. It is the proportion of variance in the dependent variable that is explained by the model.

# %% [markdown]
# ### Interpretation of the coefficient of determination-
# - proportion of variance in the dependent variable that is predicted by the statistical model.
# - 92% of the variance in the house price is predicted by all independent variables.
# - 8% of the variance in in the house price is unexplained by the model

# %% [markdown]
# ### VERY IMPORTANT
# - The coefficient of determination (R²) is only used for simple linear regression
# - For multiple linear regression, we use **adjusted R²**.
# - Adjusted R-squared, a modified version of R-squared, adds precision and reliability by considering the impact of additional independent variables that tend to skew the results of R-squared measurements.

# %%
N=x.shape[0] # shape is 0
p=5 # number of features
x = (1-r2)
y = (N-1) / (N-p-1)
adj_rsquared = (1 - (x * y))
print("Adjusted-R2 : " , adj_rsquared)
# Out:
# Adjusted-R2 :  0.9182072722085004

# %% [markdown]
# - It will always be smaller than R-squared value

# %% [markdown]
# ### Mean of residuals
# - It should be close to zero

# %%
residuals = y_train.values-y_pred
mean_residuals = np.mean(residuals)
print("Mean of Residuals {}".format(mean_residuals))
# Out:
# Mean of Residuals 1.839051644007365e-10

# %% [markdown]
# It is very close to 0. Hence, all good.

# %% [markdown]
# ###  Homoscedasticity
# - Homoscedasticity means that they are roughly the same throughout, which means your residuals do not suddenly get larger

# %%
p = sns.scatterplot(y_pred, residuals)
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
p = sns.lineplot([0,2.6],[0,0],color='blue')
p = plt.title('Residuals vs fitted values plot for homoscedasticity check')
# Out:
# C:\Users\sandy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Errors should be normally distributed

# %%
sns.distplot((y_train-y_pred),bins=50)
# Out:
# C:\Users\sandy\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# ## Predictions from our Model
#
# Let's grab predictions off our test set and see how well it did!

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %% [markdown]
# - Graph suggests that actual value and predicted values are very clost to each other. As there is not mauch scatter.

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 81877.46809001947
# MSE: 10364756049.538454
# RMSE: 101807.44594349891

# %% [markdown]
# ### Feature selection
# #### Backward elimination technique

# %%
import statsmodels.api as sm
y = USAhousing.Price
x = USAhousing[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
               'Avg. Area Number of Bedrooms', 'Area Population']]
#Adding constant column of ones, mandatory for sm.OLS model
X_1 = sm.add_constant(x)
# Fitting sm.OLS model
model = sm.OLS(y, X_1).fit()
model.pvalues
# Out:
# C:\Users\sandy\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# const                           0.000000
# Avg. Area Income                0.000000
# Avg. Area House Age             0.000000
# Avg. Area Number of Rooms       0.000000
# Avg. Area Number of Bedrooms    0.207119
# Area Population                 0.000000
# dtype: float64

# %% [markdown]
# - Variable Avg. Area Number of Bedrooms has highest p value and it is also not significant (p > 0.05).
# - Rest other variables are significant (p < 0.05).
# - Hence, we can remove Avg. Area Number of Bedrooms columns from the model.

# %% [markdown]
# - From here we can remove average area number of bedrooms column and try to run the whole model again
